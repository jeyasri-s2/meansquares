# %% [markdown]
# <a href="https://colab.research.google.com/github/aarsanjani/meansquares/blob/master/TimeSeriesAnalysis_VAR.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Workflow
# This colab uses the labeled CA data for Multivariate time series forecasting called Vector Autoregression
# (VAR).

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

from tqdm import tqdm
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import os
from pandas import Series, datetime
from pandas.plotting import scatter_matrix, autocorrelation_plot
from sklearn.preprocessing import StandardScaler, RobustScaler
from sklearn.model_selection import train_test_split, KFold, cross_val_score, GridSearchCV, TimeSeriesSplit
from sklearn import metrics
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score, mean_squared_error
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.naive_bayes import GaussianNB
from sklearn.cluster import KMeans
from sklearn.svm import SVC
from sklearn.ensemble import AdaBoostClassifier, GradientBoostingClassifier, RandomForestClassifier, ExtraTreesClassifier
from sklearn.metrics import roc_curve, auc
import random
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from statsmodels.tsa.arima_model import ARIMA
from xgboost import XGBClassifier
from sklearn.mixture import GaussianMixture


import statsmodels.api as sm
from statsmodels.tsa.api import VAR
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %% [markdown]
# # Load Data

# %%
NY_labeled_data = pd.read_csv('/content/drive/Shared drives/CMPE 295- Master Project/Covid19-data/NY_labeledData_Sep26.csv',low_memory=False)
NY_labeled_data.head()
# Out:
#          Date  fips_x  ... growth_label_1k  growth_1k_pop
# 0  2020-03-01   36001  ...     flat_growth            0.0
# 1  2020-03-01   36123  ...     flat_growth            0.0
# 2  2020-03-01   36021  ...     flat_growth            0.0
# 3  2020-03-01   36095  ...     flat_growth            0.0
# 4  2020-03-01   36033  ...     flat_growth            0.0
#
# [5 rows x 23 columns]

# %%
NY_labeled_data.columns
# Out:
# Index(['Date', 'fips_x', 'County Name', 'retail and recreation',
#        'grocery and pharmacy', 'parks', 'transit stations', 'workplaces',
#        'residential', 'driving', 'm50', 'm50_index', 'population_density',
#        'mask_rule_active', 'mask_wearing_percent', 'New cases',
#        'rolling_avg_new_cases', 'population', 'label', 'growth_label',
#        'New Cases/1k population', 'growth_label_1k', 'growth_1k_pop'],
#       dtype='object')

# %%
columns = ['retail and recreation',
       'grocery and pharmacy', 'parks', 'transit stations', 'workplaces',
       'residential', 'driving', 'm50', 'm50_index', 'population_density',
       'mask_rule_active', 'mask_wearing_percent','New Cases/1k population']

NY_labeled_data_filter = NY_labeled_data.filter(columns, axis=1)

# %%
NY_labeled_data_filter.head(3)
# Out:
#    retail and recreation  ...  New Cases/1k population
# 0                   10.0  ...                      0.0
# 1                   31.0  ...                      0.0
# 2                   21.0  ...                      0.0
#
# [3 rows x 13 columns]

# %% [markdown]
# # VAR- Implementation -Analytic Vidya + Old Code

# %%
NY_labeled_data['County Name'].unique
# Out:
# <bound method Series.unique of 0          Albany County
# 1           Yates County
# 2        Columbia County
# 3       Schoharie County
# 4        Franklin County
#               ...
# 9799       Seneca County
# 9800     Cortland County
# 9801      Steuben County
# 9802      Suffolk County
# 9803        Yates County
# Name: County Name, Length: 9804, dtype: object>

# %%
NY_labeled_data[NY_labeled_data['County Name']=='New York County']
# Out:
#             Date  fips_x  ... growth_label_1k  growth_1k_pop
# 37    2020-03-01   36061  ...     flat_growth       0.000000
# 60    2020-03-02   36061  ...     mild_growth       0.000614
# 161   2020-03-03   36061  ...     flat_growth       0.000000
# 184   2020-03-04   36061  ...     flat_growth       0.000000
# 242   2020-03-05   36061  ...     mild_growth       0.001842
# ...          ...     ...  ...             ...            ...
# 9537  2020-08-17   36061  ...     mild_growth       0.131408
# 9598  2020-08-18   36061  ...     mild_growth       0.161279
# 9665  2020-08-19   36061  ...     mild_growth       0.121926
# 9690  2020-08-20   36061  ...     mild_growth       0.167618
# 9794  2020-08-21   36061  ...     mild_growth       0.087432
#
# [172 rows x 23 columns]

# %% [markdown]
# ## Filter Data

# %%
columns = ['Date', 'fips_x','retail and recreation',
       'grocery and pharmacy', 'parks', 'transit stations', 'workplaces',
       'residential', 'driving', 'm50', 'm50_index', 
       'mask_rule_active', 'mask_wearing_percent','New Cases/1k population']

#NY_labeled_data_filter = NY_labeled_data.filter(columns, axis=1)
NY_labeled_data_filter = NY_labeled_data[NY_labeled_data['County Name']=='New York County'].filter(columns, axis=1)

# %%
NY_labeled_data_filter.shape
# Out:
# (172, 14)

# %%
NY_labeled_data_filter.isnull().sum()
# Out:
# Date                       0
# fips_x                     0
# retail and recreation      0
# grocery and pharmacy       0
# parks                      0
# transit stations           0
# workplaces                 0
# residential                0
# driving                    0
# m50                        0
# m50_index                  0
# mask_rule_active           0
# mask_wearing_percent       0
# New Cases/1k population    0
# dtype: int64

# %%
NY_labeled_data_filter.index
# Out:
# Int64Index([  37,   60,  161,  184,  242,  331,  349,  416,  502,  533,
#             ...
#             9267, 9302, 9356, 9407, 9482, 9537, 9598, 9665, 9690, 9794],
#            dtype='int64', length=172)

# %%
NY_labeled_data_filter.describe()
# Out:
#         fips_x  ...  New Cases/1k population
# count    172.0  ...               172.000000
# mean   36061.0  ...                 0.814964
# std        0.0  ...                 1.014345
# min    36061.0  ...                 0.000000
# 25%    36061.0  ...                 0.184349
# 50%    36061.0  ...                 0.256338
# 75%    36061.0  ...                 1.162272
# max    36061.0  ...                 4.811795
#
# [8 rows x 13 columns]

# %% [markdown]
# ## Make Date Index

# %%
NY_labeled_data_filter.tail(2)
# Out:
#             Date  fips_x  ...  mask_wearing_percent  New Cases/1k population
# 9690  2020-08-20   36061  ...                 0.803                 0.167618
# 9794  2020-08-21   36061  ...                 0.803                 0.175600
#
# [2 rows x 14 columns]

# %%
NY_labeled_data_filter['Date_Time'] = pd.to_datetime(NY_labeled_data_filter['Date'])

# %%
NY_labeled_data_filter = NY_labeled_data_filter.set_index('Date_Time')

# %%
NY_labeled_data_filter.head(2)
# Out:
#                   Date  fips_x  ...  mask_wearing_percent  New Cases/1k population
# Date_Time                       ...
# 2020-03-01  2020-03-01   36061  ...                   0.0                 0.000000
# 2020-03-02  2020-03-02   36061  ...                   0.0                 0.000614
#
# [2 rows x 14 columns]

# %%
NY_labeled_data_filter = NY_labeled_data_filter.drop(['Date','fips_x'], axis=1)
NY_labeled_data_filter.head(2)
# Out:
#             retail and recreation  ...  New Cases/1k population
# Date_Time                          ...
# 2020-03-01                   -3.0  ...                 0.000000
# 2020-03-02                    3.0  ...                 0.000614
#
# [2 rows x 12 columns]

# %%
NY_labeled_data_filter
# Out:
#             retail and recreation  ...  New Cases/1k population
# Date_Time                          ...
# 2020-03-01                   -3.0  ...                 0.000000
# 2020-03-02                    3.0  ...                 0.000614
# 2020-03-03                    0.0  ...                 0.000000
# 2020-03-04                    3.0  ...                 0.000000
# 2020-03-05                    2.0  ...                 0.001842
# ...                           ...  ...                      ...
# 2020-08-17                    0.0  ...                 0.144286
# 2020-08-18                    0.0  ...                 0.174372
# 2020-08-19                    0.0  ...                 0.167618
# 2020-08-20                    0.0  ...                 0.167618
# 2020-08-21                    0.0  ...                 0.175600
#
# [172 rows x 12 columns]

# %% [markdown]
# ## Checking Stationarity- Eigen Value
#
# we understood that if the modulus of eigenvalues are less than 1, the series would be classified as stationary.

# %%
NY_labeled_data_filter.columns
# Out:
# Index(['retail and recreation', 'grocery and pharmacy', 'parks',
#        'transit stations', 'workplaces', 'residential', 'driving', 'm50',
#        'm50_index', 'mask_rule_active', 'mask_wearing_percent',
#        'New Cases/1k population'],
#       dtype='object')

# %%
from statsmodels.tsa.vector_ar.vecm import coint_johansen
#since the test works for only 12 variables, I have randomly dropped
#in the next iteration, I would drop another and check the eigenvalues
johan_test_temp = NY_labeled_data_filter.drop(['driving'], axis=1) ## this column is giving neg value for eigen
coint_johansen(johan_test_temp,-1,1).eig
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tsa/vector_ar/vecm.py:674: RuntimeWarning: invalid value encountered in log
#   tmp = np.log(iota - a)[i:]
# /usr/local/lib/python3.6/dist-packages/statsmodels/tsa/vector_ar/vecm.py:676: RuntimeWarning: invalid value encountered in log
#   lr2[i] = -t * np.log(1-a[i])
# array([ 4.63603881,  0.5112707 ,  0.38204253,  0.24226716,  0.17809857,
#         0.14118623,  0.11675866,  0.03503089,  0.00521361, -0.024701  ,
#        -2.16780158])

# %% [markdown]
# ##Stationarity

# %% [markdown]
# A stationary time series will more often than not give us a better set of predictions. Similar to the Augmented Dickey-Fuller test for univariate series, we have Johansen’s test for checking the stationarity of any multivariate time series data. Since the test works for only 12 variables, I have randomly dropped in the next iteration, I would drop another and check the eigenvalues.
#
# coint_johansen()
# statsmodels.tsa.vector_ar.vecm.coint_johansen(endog, det_order, k_ar_diff) - perform the Johansen cointegration test for determining the cointegration rank of a VECM.
#
# endog - the data with presample.
# det_order: int -
# -1 - no deterministic terms.
# 0 - constant term.
# 1 - linear trend.
# k_ar_diff: int, nonnegative - number of lagged differences in the model.

# %%
# Augmented Dickey-Fuller Test (ADF Test)/unit root test-not using this
from statsmodels.tsa.stattools import adfuller
def adf_test(ts, signif=0.05):
  dftest = adfuller(ts, autolag='AIC')
  adf = pd.Series(dftest[0:4], index=['Test Statistic','p-value','# Lags','# Observations'])
  for key,value in dftest[4].items():
    adf['Critical Value (%s)'%key] = value
  print (adf)
  p = adf['p-value']
  if p <= signif:
    print(f" Series is Stationary")
  else:
    print(f" Series is Non-Stationary")

# %%
#apply adf test on the series-not using this


for i in train.columns:
  print(i)
  #adf_test(train[[i]])
adf_test(train["retail and recreation"])
# Out:
# retail and recreation
# grocery and pharmacy
# parks
# transit stations
# workplaces
# m50
# mask_rule_active
# mask_wearing_percent
# New Cases/1k population
# Test Statistic         -6.886872e+00
# p-value                 1.387366e-09
# # Lags                  1.400000e+01
# # Observations          1.470000e+02
# Critical Value (1%)    -3.475637e+00
# Critical Value (5%)    -2.881410e+00
# Critical Value (10%)   -2.577365e+00
# dtype: float64
#  Series is Stationary

# %%
def adfuller_test(series, signif=0.05, name='', verbose=False):
    """Perform ADFuller to test for Stationarity of given series and print report"""
    r = adfuller(series, autolag='AIC')
    output = {'test_statistic':round(r[0], 4), 'pvalue':round(r[1], 4), 'n_lags':round(r[2], 4), 'n_obs':r[3]}
    p_value = output['pvalue'] 
    def adjust(val, length= 6): return str(val).ljust(length)

    # Print Summary
    print(f'    Augmented Dickey-Fuller Test on "{name}"', "\n   ", '-'*47)
    print(f' Null Hypothesis: Data has unit root. Non-Stationary.')
    print(f' Significance Level    = {signif}')
    print(f' Test Statistic        = {output["test_statistic"]}')
    print(f' No. Lags Chosen       = {output["n_lags"]}')

    for key,val in r[4].items():
        print(f' Critical value {adjust(key)} = {round(val, 3)}')

    if p_value <= signif:
        print(f" => P-Value = {p_value}. Rejecting Null Hypothesis.")
        print(f" => Series is Stationary.")
    else:
        print(f" => P-Value = {p_value}. Weak evidence to reject the Null Hypothesis.")
        print(f" => Series is Non-Stationary.")

# %%
# ADF Test on each column
train = johan_test_temp

for name, column in train.iteritems():
    adfuller_test(column, name=column.name)
    print('\n')
# Out:
#     Augmented Dickey-Fuller Test on "retail and recreation"
#     -----------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = -0.8686
#  No. Lags Chosen       = 13
#  Critical value 1%     = -3.472
#  Critical value 5%     = -2.88
#  Critical value 10%    = -2.577
#  => P-Value = 0.7981. Weak evidence to reject the Null Hypothesis.
#  => Series is Non-Stationary.
#
#
#     Augmented Dickey-Fuller Test on "grocery and pharmacy"
#     -----------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = -2.2693
#  No. Lags Chosen       = 7
#  Critical value 1%     = -3.471
#  Critical value 5%     = -2.879
#  Critical value 10%    = -2.576
#  => P-Value = 0.1821. Weak evidence to reject the Null Hypothesis.
#  => Series is Non-Stationary.
#
#
#     Augmented Dickey-Fuller Test on "parks"
#     -----------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = -2.0036
#  No. Lags Chosen       = 7
#  Critical value 1%     = -3.471
#  Critical value 5%     = -2.879
#  Critical value 10%    = -2.576
#  => P-Value = 0.285. Weak evidence to reject the Null Hypothesis.
#  => Series is Non-Stationary.
#
#
#     Augmented Dickey-Fuller Test on "transit stations"
#     -----------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = -1.5204
#  No. Lags Chosen       = 1
#  Critical value 1%     = -3.469
#  Critical value 5%     = -2.879
#  Critical value 10%    = -2.576
#  => P-Value = 0.5234. Weak evidence to reject the Null Hypothesis.
#  => Series is Non-Stationary.
#
#
#     Augmented Dickey-Fuller Test on "workplaces"
#     -----------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = -5.2652
#  No. Lags Chosen       = 11
#  Critical value 1%     = -3.472
#  Critical value 5%     = -2.88
#  Critical value 10%    = -2.576
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#     Augmented Dickey-Fuller Test on "residential"
#     -----------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = -2.7246
#  No. Lags Chosen       = 12
#  Critical value 1%     = -3.472
#  Critical value 5%     = -2.88
#  Critical value 10%    = -2.577
#  => P-Value = 0.0699. Weak evidence to reject the Null Hypothesis.
#  => Series is Non-Stationary.
#
#
#     Augmented Dickey-Fuller Test on "m50"
#     -----------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = -4.884
#  No. Lags Chosen       = 8
#  Critical value 1%     = -3.471
#  Critical value 5%     = -2.879
#  Critical value 10%    = -2.576
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#     Augmented Dickey-Fuller Test on "m50_index"
#     -----------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = -4.8658
#  No. Lags Chosen       = 8
#  Critical value 1%     = -3.471
#  Critical value 5%     = -2.879
#  Critical value 10%    = -2.576
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#     Augmented Dickey-Fuller Test on "mask_rule_active"
#     -----------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = -1.6823
#  No. Lags Chosen       = 0
#  Critical value 1%     = -3.469
#  Critical value 5%     = -2.879
#  Critical value 10%    = -2.576
#  => P-Value = 0.4403. Weak evidence to reject the Null Hypothesis.
#  => Series is Non-Stationary.
#
#
#     Augmented Dickey-Fuller Test on "mask_wearing_percent"
#     -----------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = -1.6823
#  No. Lags Chosen       = 0
#  Critical value 1%     = -3.469
#  Critical value 5%     = -2.879
#  Critical value 10%    = -2.576
#  => P-Value = 0.4403. Weak evidence to reject the Null Hypothesis.
#  => Series is Non-Stationary.
#
#
#     Augmented Dickey-Fuller Test on "New Cases/1k population"
#     -----------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = -2.4491
#  No. Lags Chosen       = 9
#  Critical value 1%     = -3.471
#  Critical value 5%     = -2.88
#  Critical value 10%    = -2.576
#  => P-Value = 0.1283. Weak evidence to reject the Null Hypothesis.
#  => Series is Non-Stationary.

# %% [markdown]
# ## Make data stationery

# %% [markdown]
# ### 1st Differencing

# %%
# 1st difference
df_differenced = train.diff().dropna()

# %%
# ADF Test on each column of 1st Differences Dataframe
for name, column in df_differenced.iteritems():
    adfuller_test(column, name=column.name)
    print('\n')
# Out:
#     Augmented Dickey-Fuller Test on "retail and recreation"
#     -----------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = -1.8855
#  No. Lags Chosen       = 12
#  Critical value 1%     = -3.472
#  Critical value 5%     = -2.88
#  Critical value 10%    = -2.577
#  => P-Value = 0.3389. Weak evidence to reject the Null Hypothesis.
#  => Series is Non-Stationary.
#
#
#     Augmented Dickey-Fuller Test on "grocery and pharmacy"
#     -----------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = -13.3162
#  No. Lags Chosen       = 1
#  Critical value 1%     = -3.47
#  Critical value 5%     = -2.879
#  Critical value 10%    = -2.576
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#     Augmented Dickey-Fuller Test on "parks"
#     -----------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = -4.9548
#  No. Lags Chosen       = 6
#  Critical value 1%     = -3.471
#  Critical value 5%     = -2.879
#  Critical value 10%    = -2.576
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#     Augmented Dickey-Fuller Test on "transit stations"
#     -----------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = -14.8619
#  No. Lags Chosen       = 0
#  Critical value 1%     = -3.469
#  Critical value 5%     = -2.879
#  Critical value 10%    = -2.576
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#     Augmented Dickey-Fuller Test on "workplaces"
#     -----------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = -2.3648
#  No. Lags Chosen       = 8
#  Critical value 1%     = -3.471
#  Critical value 5%     = -2.88
#  Critical value 10%    = -2.576
#  => P-Value = 0.1519. Weak evidence to reject the Null Hypothesis.
#  => Series is Non-Stationary.
#
#
#     Augmented Dickey-Fuller Test on "residential"
#     -----------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = -2.8971
#  No. Lags Chosen       = 11
#  Critical value 1%     = -3.472
#  Critical value 5%     = -2.88
#  Critical value 10%    = -2.577
#  => P-Value = 0.0457. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#     Augmented Dickey-Fuller Test on "m50"
#     -----------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = -3.6084
#  No. Lags Chosen       = 6
#  Critical value 1%     = -3.471
#  Critical value 5%     = -2.879
#  Critical value 10%    = -2.576
#  => P-Value = 0.0056. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#     Augmented Dickey-Fuller Test on "m50_index"
#     -----------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = -3.6058
#  No. Lags Chosen       = 6
#  Critical value 1%     = -3.471
#  Critical value 5%     = -2.879
#  Critical value 10%    = -2.576
#  => P-Value = 0.0057. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#     Augmented Dickey-Fuller Test on "mask_rule_active"
#     -----------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = -13.0384
#  No. Lags Chosen       = 0
#  Critical value 1%     = -3.469
#  Critical value 5%     = -2.879
#  Critical value 10%    = -2.576
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#     Augmented Dickey-Fuller Test on "mask_wearing_percent"
#     -----------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = -13.0384
#  No. Lags Chosen       = 0
#  Critical value 1%     = -3.469
#  Critical value 5%     = -2.879
#  Critical value 10%    = -2.576
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#     Augmented Dickey-Fuller Test on "New Cases/1k population"
#     -----------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = -2.2115
#  No. Lags Chosen       = 8
#  Critical value 1%     = -3.471
#  Critical value 5%     = -2.88
#  Critical value 10%    = -2.576
#  => P-Value = 0.2021. Weak evidence to reject the Null Hypothesis.
#  => Series is Non-Stationary.

# %% [markdown]
# ### 2nd Differencing

# %%
# Second Differencing
df_differenced = df_differenced.diff().dropna()

# %%
# ADF Test on each column of 2nd Differences Dataframe
for name, column in df_differenced.iteritems():
    adfuller_test(column, name=column.name)
    print('\n')
# Out:
#     Augmented Dickey-Fuller Test on "retail and recreation"
#     -----------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = -5.9127
#  No. Lags Chosen       = 10
#  Critical value 1%     = -3.472
#  Critical value 5%     = -2.88
#  Critical value 10%    = -2.577
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#     Augmented Dickey-Fuller Test on "grocery and pharmacy"
#     -----------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = -5.7682
#  No. Lags Chosen       = 9
#  Critical value 1%     = -3.472
#  Critical value 5%     = -2.88
#  Critical value 10%    = -2.576
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#     Augmented Dickey-Fuller Test on "parks"
#     -----------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = -7.834
#  No. Lags Chosen       = 13
#  Critical value 1%     = -3.473
#  Critical value 5%     = -2.88
#  Critical value 10%    = -2.577
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#     Augmented Dickey-Fuller Test on "transit stations"
#     -----------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = -3.5061
#  No. Lags Chosen       = 13
#  Critical value 1%     = -3.473
#  Critical value 5%     = -2.88
#  Critical value 10%    = -2.577
#  => P-Value = 0.0078. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#     Augmented Dickey-Fuller Test on "workplaces"
#     -----------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = -8.6501
#  No. Lags Chosen       = 9
#  Critical value 1%     = -3.472
#  Critical value 5%     = -2.88
#  Critical value 10%    = -2.576
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#     Augmented Dickey-Fuller Test on "residential"
#     -----------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = -6.2022
#  No. Lags Chosen       = 12
#  Critical value 1%     = -3.473
#  Critical value 5%     = -2.88
#  Critical value 10%    = -2.577
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#     Augmented Dickey-Fuller Test on "m50"
#     -----------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = -7.4512
#  No. Lags Chosen       = 13
#  Critical value 1%     = -3.473
#  Critical value 5%     = -2.88
#  Critical value 10%    = -2.577
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#     Augmented Dickey-Fuller Test on "m50_index"
#     -----------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = -7.5354
#  No. Lags Chosen       = 13
#  Critical value 1%     = -3.473
#  Critical value 5%     = -2.88
#  Critical value 10%    = -2.577
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#     Augmented Dickey-Fuller Test on "mask_rule_active"
#     -----------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = -8.1504
#  No. Lags Chosen       = 6
#  Critical value 1%     = -3.471
#  Critical value 5%     = -2.879
#  Critical value 10%    = -2.576
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#     Augmented Dickey-Fuller Test on "mask_wearing_percent"
#     -----------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = -8.1504
#  No. Lags Chosen       = 6
#  Critical value 1%     = -3.471
#  Critical value 5%     = -2.879
#  Critical value 10%    = -2.576
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#     Augmented Dickey-Fuller Test on "New Cases/1k population"
#     -----------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = -14.1784
#  No. Lags Chosen       = 7
#  Critical value 1%     = -3.471
#  Critical value 5%     = -2.88
#  Critical value 10%    = -2.576
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.

# %% [markdown]
# ## Checking Eigen Value Again

# %%
df_differenced.columns
# Out:
# Index(['retail and recreation', 'grocery and pharmacy', 'parks',
#        'transit stations', 'workplaces', 'residential', 'm50', 'm50_index',
#        'mask_rule_active', 'mask_wearing_percent', 'New Cases/1k population'],
#       dtype='object')

# %%
johan_test_temp = df_differenced.drop(['m50_index','residential'], axis=1) ## this column is giving neg value for eigen

# %% [markdown]
# ##Train-Validation Split

# %%
#creating the train and validation set
train = johan_test_temp[:int(0.8*(len(data)))]
print(train.shape)
valid = johan_test_temp[int(0.8*(len(data))):]
print(valid.shape)
# Out:
# (162, 9)
# (8, 9)

# %% [markdown]
# ## VAR

# %%
#fit the model
from statsmodels.tsa.vector_ar.var_model import VAR

model = VAR(endog=train)
model_fit = model.fit()

# make prediction on validation
prediction = model_fit.forecast(model_fit.y, steps=len(valid))
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tsa/base/tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# /usr/local/lib/python3.6/dist-packages/statsmodels/base/wrapper.py:35: FutureWarning: y is a deprecated alias for endog, will be removed in version 0.11.0
#   obj = getattr(results, attr)

# %%
model_fit.summary()
# Out:
#   Summary of Regression Results
# ==================================
# Model:                         VAR
# Method:                        OLS
# Date:           Sun, 18, Oct, 2020
# Time:                     03:21:50
# --------------------------------------------------------------------
# No. of Equations:         9.00000    BIC:                   -29.8084
# Nobs:                     161.000    HQIC:                  -30.8315
# Log likelihood:           572.200    FPE:                2.02724e-14
# AIC:                     -31.5310    Det(Omega_mle):     1.71256e-14
# --------------------------------------------------------------------
# Results for equation retail and recreation
# ==============================================================================================
#                                 coefficient        std. error           t-stat            prob
# ----------------------------------------------------------------------------------------------
# const                             -0.022418          0.306903           -0.073           0.942
# L1.retail and recreation          -0.352776          0.116633           -3.025           0.002
# L1.grocery and pharmacy           -0.086573          0.053177           -1.628           0.104
# L1.parks                          -0.035743          0.023837           -1.499           0.134
# L1.transit stations               -0.145374          0.138268           -1.051           0.293
# L1.workplaces                      0.047601          0.024173            1.969           0.049
# L1.m50                            -0.998198          1.150050           -0.868           0.385
# L1.mask_rule_active               -2.198051  234054324.251198           -0.000           1.000
# L1.mask_wearing_percent           -1.765035  291474874.534493           -0.000           1.000
# L1.New Cases/1k population         0.231663          0.731251            0.317           0.751
# ==============================================================================================
#
# Results for equation grocery and pharmacy
# ==============================================================================================
#                                 coefficient        std. error           t-stat            prob
# ----------------------------------------------------------------------------------------------
# const                             -0.015783          0.712635           -0.022           0.982
# L1.retail and recreation           0.274636          0.270825            1.014           0.311
# L1.grocery and pharmacy           -0.483117          0.123479           -3.913           0.000
# L1.parks                          -0.137675          0.055351           -2.487           0.013
# L1.transit stations               -0.264534          0.321061           -0.824           0.410
# L1.workplaces                      0.039319          0.056130            0.700           0.484
# L1.m50                             1.081591          2.670443            0.405           0.685
# L1.mask_rule_active               -8.158685  543479464.740323           -0.000           1.000
# L1.mask_wearing_percent           -6.551424  676811288.593180           -0.000           1.000
# L1.New Cases/1k population         2.619345          1.697980            1.543           0.123
# ==============================================================================================
#
# Results for equation parks
# ===============================================================================================
#                                 coefficient         std. error           t-stat            prob
# -----------------------------------------------------------------------------------------------
# const                             -0.088960           1.695049           -0.052           0.958
# L1.retail and recreation           0.145824           0.644174            0.226           0.821
# L1.grocery and pharmacy            0.235938           0.293703            0.803           0.422
# L1.parks                          -0.717446           0.131656           -5.449           0.000
# L1.transit stations               -0.528720           0.763663           -0.692           0.489
# L1.workplaces                      0.105828           0.133509            0.793           0.428
# L1.m50                             0.061284           6.351818            0.010           0.992
# L1.mask_rule_active              -13.290160  1292700614.363401           -0.000           1.000
# L1.mask_wearing_percent          -10.671999  1609838872.183564           -0.000           1.000
# L1.New Cases/1k population         4.999482           4.038755            1.238           0.216
# ===============================================================================================
#
# Results for equation transit stations
# ==============================================================================================
#                                 coefficient        std. error           t-stat            prob
# ----------------------------------------------------------------------------------------------
# const                             -0.007784          0.323053           -0.024           0.981
# L1.retail and recreation           0.023142          0.122771            0.188           0.850
# L1.grocery and pharmacy            0.036342          0.055976            0.649           0.516
# L1.parks                          -0.043605          0.025092           -1.738           0.082
# L1.transit stations               -0.705243          0.145544           -4.846           0.000
# L1.workplaces                      0.073143          0.025445            2.875           0.004
# L1.m50                             1.567565          1.210570            1.295           0.195
# L1.mask_rule_active               -2.561370  246371196.394181           -0.000           1.000
# L1.mask_wearing_percent           -2.056780  306813445.073699           -0.000           1.000
# L1.New Cases/1k population         0.768451          0.769732            0.998           0.318
# ==============================================================================================
#
# Results for equation workplaces
# ===============================================================================================
#                                 coefficient         std. error           t-stat            prob
# -----------------------------------------------------------------------------------------------
# const                              0.060087           1.789239            0.034           0.973
# L1.retail and recreation          -1.357871           0.679969           -1.997           0.046
# L1.grocery and pharmacy            0.501946           0.310023            1.619           0.105
# L1.parks                          -0.181741           0.138972           -1.308           0.191
# L1.transit stations                0.375569           0.806099            0.466           0.641
# L1.workplaces                     -0.250253           0.140928           -1.776           0.076
# L1.m50                            16.222966           6.704775            2.420           0.016
# L1.mask_rule_active              -12.681005  1364533209.252869           -0.000           1.000
# L1.mask_wearing_percent          -10.182847  1699294158.471817           -0.000           1.000
# L1.New Cases/1k population         6.707043           4.263180            1.573           0.116
# ===============================================================================================
#
# Results for equation m50
# =============================================================================================
#                                 coefficient       std. error           t-stat            prob
# ---------------------------------------------------------------------------------------------
# const                             -0.002459         0.019755           -0.124           0.901
# L1.retail and recreation          -0.016496         0.007507           -2.197           0.028
# L1.grocery and pharmacy            0.005314         0.003423            1.552           0.121
# L1.parks                           0.000630         0.001534            0.411           0.681
# L1.transit stations               -0.000378         0.008900           -0.042           0.966
# L1.workplaces                     -0.003448         0.001556           -2.216           0.027
# L1.m50                            -0.400988         0.074026           -5.417           0.000
# L1.mask_rule_active                0.031466  15065521.048930            0.000           1.000
# L1.mask_wearing_percent            0.025267  18761545.515479            0.000           1.000
# L1.New Cases/1k population        -0.003934         0.047069           -0.084           0.933
# =============================================================================================
#
# Results for equation mask_rule_active
# =============================================================================================
#                                 coefficient       std. error           t-stat            prob
# ---------------------------------------------------------------------------------------------
# const                             -0.000150         0.007322           -0.020           0.984
# L1.retail and recreation          -0.003159         0.002783           -1.135           0.256
# L1.grocery and pharmacy            0.002883         0.001269            2.272           0.023
# L1.parks                          -0.000431         0.000569           -0.758           0.448
# L1.transit stations                0.003331         0.003299            1.010           0.313
# L1.workplaces                     -0.000706         0.000577           -1.224           0.221
# L1.m50                             0.001606         0.027438            0.059           0.953
# L1.mask_rule_active               -0.407228   5584114.629997           -0.000           1.000
# L1.mask_wearing_percent           -0.327004   6954065.541714           -0.000           1.000
# L1.New Cases/1k population         0.059357         0.017446            3.402           0.001
# =============================================================================================
#
# Results for equation mask_wearing_percent
# =============================================================================================
#                                 coefficient       std. error           t-stat            prob
# ---------------------------------------------------------------------------------------------
# const                             -0.000120         0.005880           -0.020           0.984
# L1.retail and recreation          -0.002537         0.002234           -1.135           0.256
# L1.grocery and pharmacy            0.002315         0.001019            2.272           0.023
# L1.parks                          -0.000346         0.000457           -0.758           0.448
# L1.transit stations                0.002675         0.002649            1.010           0.313
# L1.workplaces                     -0.000567         0.000463           -1.224           0.221
# L1.m50                             0.001290         0.022033            0.059           0.953
# L1.mask_rule_active               -0.327004   4484044.047887           -0.000           1.000
# L1.mask_wearing_percent           -0.262585   5584114.629997           -0.000           1.000
# L1.New Cases/1k population         0.047664         0.014009            3.402           0.001
# =============================================================================================
#
# Results for equation New Cases/1k population
# =============================================================================================
#                                 coefficient       std. error           t-stat            prob
# ---------------------------------------------------------------------------------------------
# const                             -0.000419         0.036560           -0.011           0.991
# L1.retail and recreation          -0.007320         0.013894           -0.527           0.598
# L1.grocery and pharmacy            0.008085         0.006335            1.276           0.202
# L1.parks                          -0.002351         0.002840           -0.828           0.408
# L1.transit stations                0.020348         0.016471            1.235           0.217
# L1.workplaces                     -0.005272         0.002880           -1.831           0.067
# L1.m50                            -0.017650         0.137001           -0.129           0.897
# L1.mask_rule_active               -1.207733  27881925.718622           -0.000           1.000
# L1.mask_wearing_percent           -0.969810  34722198.902394           -0.000           1.000
# L1.New Cases/1k population        -0.238531         0.087111           -2.738           0.006
# =============================================================================================
#
# Correlation matrix of residuals
#                            retail and recreation  grocery and pharmacy     parks  transit stations  workplaces       m50  mask_rule_active  mask_wearing_percent  New Cases/1k population
# retail and recreation                   1.000000              0.675328  0.628821          0.494598    0.020642  0.255015          0.073295              0.073295                 0.031830
# grocery and pharmacy                    0.675328              1.000000  0.771400          0.756295    0.522458  0.033537         -0.002959             -0.002959                 0.092094
# parks                                   0.628821              0.771400  1.000000          0.787253    0.579592  0.001303         -0.018533             -0.018533                 0.050276
# transit stations                        0.494598              0.756295  0.787253          1.000000    0.781110 -0.084794         -0.012676             -0.012676                 0.084670
# workplaces                              0.020642              0.522458  0.579592          0.781110    1.000000 -0.309222         -0.043565             -0.043565                 0.111088
# m50                                     0.255015              0.033537  0.001303         -0.084794   -0.309222  1.000000         -0.002109             -0.002109                -0.020057
# mask_rule_active                        0.073295             -0.002959 -0.018533         -0.012676   -0.043565 -0.002109          1.000000              1.000000                 0.634342
# mask_wearing_percent                    0.073295             -0.002959 -0.018533         -0.012676   -0.043565 -0.002109          1.000000              1.000000                 0.634342
# New Cases/1k population                 0.031830              0.092094  0.050276          0.084670    0.111088 -0.020057          0.634342              0.634342                 1.000000

# %% [markdown]
# ##RMSE

# %%
#converting predictions to dataframe
import math
pred = pd.DataFrame(index=range(0,len(prediction)),columns=valid.columns)
for j in range(0,len(valid.columns)):
    for i in range(0, len(prediction)):
       pred.iloc[i][j] = prediction[i][j]

#check rmse
cols=valid.columns
for i in cols:
    print('rmse value for', i, 'is : ', math.sqrt(mean_squared_error(pred[i], valid[i])))
# Out:
# rmse value for retail and recreation is :  37.15672363307146
# rmse value for grocery and pharmacy is :  21.737653478449904
# rmse value for parks is :  50.12599900680557
# rmse value for transit stations is :  33.66263329781221
# rmse value for workplaces is :  23.25231673217527
# rmse value for m50 is :  0.7389251293221982
# rmse value for mask_rule_active is :  0.0019095250442217621
# rmse value for mask_wearing_percent is :  0.0015333486105100734
# rmse value for New Cases/1k population is :  0.06015380278656014

# %% [markdown]
# ## Final Prediction

# %%
johan_test_temp.columns
# Out:
# Index(['retail and recreation', 'grocery and pharmacy', 'parks',
#        'transit stations', 'workplaces', 'm50', 'mask_rule_active',
#        'mask_wearing_percent', 'New Cases/1k population'],
#       dtype='object')

# %%
#from statsmodels.tsa.vector_ar.vecm import coint_johansen

#johan_test_temp = NY_labeled_data_filter.drop(['driving','m50_index','residential'], axis=1)

#johan_test_temp = NY_labeled_data_filter.drop(['New Cases/1k population'], axis=1) ## this column is giving neg value for eigen
#coint_johansen(johan_test_temp,-1,1).eig

# %%
# Make final predictions
print(NY_labeled_data_filter)
model = VAR(endog=johan_test_temp)
results = model.fit()
# Out:
#             retail and recreation  ...  New Cases/1k population
# Date_Time                          ...
# 2020-03-01                   -3.0  ...                 0.000000
# 2020-03-02                    3.0  ...                 0.000614
# 2020-03-03                    0.0  ...                 0.000000
# 2020-03-04                    3.0  ...                 0.000000
# 2020-03-05                    2.0  ...                 0.001842
# ...                           ...  ...                      ...
# 2020-08-17                    0.0  ...                 0.144286
# 2020-08-18                    0.0  ...                 0.174372
# 2020-08-19                    0.0  ...                 0.167618
# 2020-08-20                    0.0  ...                 0.167618
# 2020-08-21                    0.0  ...                 0.175600
#
# [172 rows x 12 columns]
# /usr/local/lib/python3.6/dist-packages/statsmodels/tsa/base/tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)

# %%
#results.summary()

# %%
yhat = results.forecast(results.y, steps=1)
print(yhat)
# Out:
# [[ 3.91757358e+00  9.00426559e-01  1.73873704e+00  2.21269079e+00
#   -1.03959380e+01  3.18150390e-01 -1.62430126e-03 -1.30431391e-03
#   -8.25208905e-03]]
# /usr/local/lib/python3.6/dist-packages/statsmodels/base/wrapper.py:35: FutureWarning: y is a deprecated alias for endog, will be removed in version 0.11.0
#   obj = getattr(results, attr)

# %%
results.plot()

# %%
results.plot_forecast(1)

# %% [markdown]
# # VAR- Implementation- Unused

# %%
NY_labeled_data['County Name'].unique
# Out:
# <bound method Series.unique of 0          Albany County
# 1           Yates County
# 2        Columbia County
# 3       Schoharie County
# 4        Franklin County
#               ...
# 9799       Seneca County
# 9800     Cortland County
# 9801      Steuben County
# 9802      Suffolk County
# 9803        Yates County
# Name: County Name, Length: 9804, dtype: object>

# %%
NY_labeled_data[NY_labeled_data['County Name']=='Albany County']
# Out:
#             Date  fips_x  ... growth_label_1k  growth_1k_pop
# 0     2020-03-01   36001  ...     flat_growth       0.000000
# 113   2020-03-02   36001  ...     flat_growth       0.000000
# 157   2020-03-03   36001  ...     flat_growth       0.000000
# 186   2020-03-04   36001  ...     flat_growth       0.000000
# 275   2020-03-05   36001  ...     flat_growth       0.000000
# ...          ...     ...  ...             ...            ...
# 9532  2020-08-17   36001  ...     mild_growth       0.009820
# 9597  2020-08-18   36001  ...  mild_decrement      -0.015099
# 9666  2020-08-19   36001  ...  mild_decrement      -0.121792
# 9708  2020-08-20   36001  ...  mild_decrement      -0.016257
# 9782  2020-08-21   36001  ...  mild_decrement      -0.013263
#
# [172 rows x 23 columns]

# %% [markdown]
# ## Filter Data

# %%
columns = ['Date', 'fips_x','retail and recreation',
       'grocery and pharmacy', 'parks', 'transit stations', 'workplaces',
       'residential', 'driving', 'm50', 'm50_index', 
       'mask_rule_active', 'mask_wearing_percent','New Cases/1k population']

#NY_labeled_data_filter = NY_labeled_data.filter(columns, axis=1)
NY_labeled_data_filter = NY_labeled_data[NY_labeled_data['County Name']=='Albany County'].filter(columns, axis=1)

# %%
NY_labeled_data_filter.shape
# Out:
# (172, 14)

# %%
NY_labeled_data_filter.isnull().sum()
# Out:
# Date                       0
# fips_x                     0
# retail and recreation      0
# grocery and pharmacy       0
# parks                      0
# transit stations           0
# workplaces                 0
# residential                0
# driving                    0
# m50                        0
# m50_index                  0
# mask_rule_active           0
# mask_wearing_percent       0
# New Cases/1k population    0
# dtype: int64

# %%
NY_labeled_data_filter.index
# Out:
# Int64Index([   0,  113,  157,  186,  275,  341,  350,  426,  496,  530,
#             ...
#             9284, 9293, 9373, 9445, 9491, 9532, 9597, 9666, 9708, 9782],
#            dtype='int64', length=172)

# %%
NY_labeled_data_filter.describe()
# Out:
#         fips_x  ...  New Cases/1k population
# count    172.0  ...               172.000000
# mean   36001.0  ...                 0.050736
# std        0.0  ...                 0.048890
# min    36001.0  ...                 0.000000
# 25%    36001.0  ...                 0.019640
# 50%    36001.0  ...                 0.039279
# 75%    36001.0  ...                 0.065465
# max    36001.0  ...                 0.320779
#
# [8 rows x 13 columns]

# %% [markdown]
# ## Make Date Index

# %%
NY_labeled_data_filter.tail(2)
# Out:
#             Date  fips_x  ...  mask_wearing_percent  New Cases/1k population
# 9708  2020-08-20   36001  ...                 0.788                 0.029459
# 9782  2020-08-21   36001  ...                 0.788                 0.022913
#
# [2 rows x 14 columns]

# %%
NY_labeled_data_filter['Date_Time'] = pd.to_datetime(NY_labeled_data_filter['Date'])

# %%
NY_labeled_data_filter = NY_labeled_data_filter.set_index('Date_Time')

# %%
NY_labeled_data_filter.head(2)
# Out:
#                   Date  fips_x  ...  mask_wearing_percent  New Cases/1k population
# Date_Time                       ...
# 2020-03-01  2020-03-01   36001  ...                   0.0                      0.0
# 2020-03-02  2020-03-02   36001  ...                   0.0                      0.0
#
# [2 rows x 14 columns]

# %%
NY_labeled_data_filter = NY_labeled_data_filter.drop(['Date','fips_x'], axis=1)
NY_labeled_data_filter.head(2)
# Out:
#             retail and recreation  ...  New Cases/1k population
# Date_Time                          ...
# 2020-03-01                   10.0  ...                      0.0
# 2020-03-02                   11.0  ...                      0.0
#
# [2 rows x 12 columns]

# %%
NY_labeled_data_filter
# Out:
#             retail and recreation  ...  New Cases/1k population
# Date_Time                          ...
# 2020-03-01                   10.0  ...                 0.000000
# 2020-03-02                   11.0  ...                 0.000000
# 2020-03-03                    8.0  ...                 0.000000
# 2020-03-04                    7.0  ...                 0.000000
# 2020-03-05                    5.0  ...                 0.000000
# ...                           ...  ...                      ...
# 2020-08-17                    0.0  ...                 0.009820
# 2020-08-18                    0.0  ...                 0.013093
# 2020-08-19                    0.0  ...                 0.045826
# 2020-08-20                    0.0  ...                 0.029459
# 2020-08-21                    0.0  ...                 0.022913
#
# [172 rows x 12 columns]

# %% [markdown]
# ## Visualize

# %%
NY_labeled_data_filter.dtypes
# Out:
# retail and recreation      float64
# grocery and pharmacy       float64
# parks                      float64
# transit stations           float64
# workplaces                 float64
# residential                float64
# driving                    float64
# m50                        float64
# m50_index                    int64
# mask_rule_active             int64
# mask_wearing_percent       float64
# New Cases/1k population    float64
# dtype: object

# %%
S1 = NY_labeled_data_filter['retail and recreation'].fillna(NY_labeled_data_filter['retail and recreation'].mean())
S2 = NY_labeled_data_filter['grocery and pharmacy'].mean()
S3 = NY_labeled_data_filter['parks'].fillna(NY_labeled_data_filter['parks'].mean())
S4 = NY_labeled_data_filter['transit stations'].fillna(NY_labeled_data_filter['transit stations'].mean())
S5 = NY_labeled_data_filter['workplaces'].fillna(NY_labeled_data_filter['workplaces'].mean())
S6 = NY_labeled_data_filter['residential'].fillna(NY_labeled_data_filter['residential'].mean())
S7 = NY_labeled_data_filter['driving'].fillna(NY_labeled_data_filter['driving'].mean())
S8 = NY_labeled_data_filter['m50'].fillna(NY_labeled_data_filter['m50'].mean())
S9 = NY_labeled_data_filter['m50_index'].fillna(NY_labeled_data_filter['m50_index'].mean())
S11 = NY_labeled_data_filter['mask_rule_active'].fillna(NY_labeled_data_filter['mask_rule_active'].mean())
S12 = NY_labeled_data_filter['mask_wearing_percent'].fillna(NY_labeled_data_filter['mask_wearing_percent'].mean())
S13 = NY_labeled_data_filter['New Cases/1k population'].fillna(NY_labeled_data_filter['New Cases/1k population'].mean())

# %%
fig, axes = plt.subplots(7,1, figsize=(15,24))

axes[0].plot(S1)
axes[0].set_title ('retail and recreation')
axes[1].plot(S2)
axes[1].set_title ('grocery and pharmacy')
axes[2].plot(S3)
axes[2].set_title ('parks')
axes[3].plot(S4)
axes[3].set_title ('transit stations')
axes[4].plot(S5)
axes[4].set_title ('workplaces')
axes[5].plot(S6)
axes[5].set_title ('residential')
axes[6].plot(S7)
axes[6].set_title ('driving')
# Out:
# Text(0.5, 1.0, 'driving')

# %%
fig, axes = plt.subplots(7,1, figsize=(15,24))

axes[0].plot(S7)
axes[0].set_title ('driving')
axes[1].plot(S8)
axes[1].set_title ('m50')
axes[2].plot(S9)
axes[2].set_title ('m50_index')
#axes[3].plot(S10)
#axes[3].set_title ('population_density')
axes[4].plot(S11)
axes[4].set_title ('mask_rule_active')
axes[5].plot(S12)
axes[5].set_title ('mask_wearing_percent')
axes[6].plot(S13)
axes[6].set_title ('New Cases/1k population')
# Out:
# Text(0.5, 1.0, 'New Cases/1k population')

# %% [markdown]
# ## Checking Stationarity- Eigen Value

# %%
NY_labeled_data_filter.columns
# Out:
# Index(['retail and recreation', 'grocery and pharmacy', 'parks',
#        'transit stations', 'workplaces', 'residential', 'driving', 'm50',
#        'm50_index', 'mask_rule_active', 'mask_wearing_percent',
#        'New Cases/1k population'],
#       dtype='object')

# %%
from statsmodels.tsa.vector_ar.vecm import coint_johansen
#since the test works for only 12 variables, I have randomly dropped
#in the next iteration, I would drop another and check the eigenvalues
johan_test_temp = NY_labeled_data_filter.drop(['grocery and pharmacy'], axis=1) ## this column is giving neg value for eigen
coint_johansen(johan_test_temp,-1,1).eig
# Out:
# array([ 0.45773428,  0.43190023,  0.32710248,  0.30736524,  0.23090548,
#         0.20054022,  0.1394041 ,  0.07961484,  0.06557554,  0.03118339,
#        -0.09315501])

# %% [markdown]
# ##Train-Validation Split

# %%
train = johan_test_temp[:int(0.8*(len(data)))]
print(train.shape)
valid = johan_test_temp[int(0.8*(len(data))):]
print(valid.shape)
# Out:
# (162, 11)
# (10, 11)

# %%
nobs = 10
train = johan_test_temp[0:-nobs]
print(train.shape)
valid = johan_test_temp[-nobs:]
print(valid.shape)
# Out:
# (162, 12)
# (10, 12)

# %% [markdown]
# ##Stationarity

# %% [markdown]
# A stationary time series will more often than not give us a better set of predictions. Similar to the Augmented Dickey-Fuller test for univariate series, we have Johansen’s test for checking the stationarity of any multivariate time series data. Since the test works for only 12 variables, I have randomly dropped in the next iteration, I would drop another and check the eigenvalues.
#
# coint_johansen()
# statsmodels.tsa.vector_ar.vecm.coint_johansen(endog, det_order, k_ar_diff) - perform the Johansen cointegration test for determining the cointegration rank of a VECM.
#
# endog - the data with presample.
# det_order: int -
# -1 - no deterministic terms.
# 0 - constant term.
# 1 - linear trend.
# k_ar_diff: int, nonnegative - number of lagged differences in the model.

# %%
# Augmented Dickey-Fuller Test (ADF Test)/unit root test-not using this
from statsmodels.tsa.stattools import adfuller
def adf_test(ts, signif=0.05):
  dftest = adfuller(ts, autolag='AIC')
  adf = pd.Series(dftest[0:4], index=['Test Statistic','p-value','# Lags','# Observations'])
  for key,value in dftest[4].items():
    adf['Critical Value (%s)'%key] = value
  print (adf)
  p = adf['p-value']
  if p <= signif:
    print(f" Series is Stationary")
  else:
    print(f" Series is Non-Stationary")

# %%
#apply adf test on the series-not using this


for i in train.columns:
  print(i)
  #adf_test(train[[i]])
adf_test(train["retail and recreation"])
# Out:
# retail and recreation
# parks
# transit stations
# workplaces
# residential
# driving
# m50
# m50_index
# mask_rule_active
# mask_wearing_percent
# New Cases/1k population
# Test Statistic           -2.011313
# p-value                   0.281635
# # Lags                   13.000000
# # Observations          148.000000
# Critical Value (1%)      -3.475325
# Critical Value (5%)      -2.881275
# Critical Value (10%)     -2.577293
# dtype: float64
#  Series is Non-Stationary

# %%
def adfuller_test(series, signif=0.05, name='', verbose=False):
    """Perform ADFuller to test for Stationarity of given series and print report"""
    r = adfuller(series, autolag='AIC')
    output = {'test_statistic':round(r[0], 4), 'pvalue':round(r[1], 4), 'n_lags':round(r[2], 4), 'n_obs':r[3]}
    p_value = output['pvalue'] 
    def adjust(val, length= 6): return str(val).ljust(length)

    # Print Summary
    print(f'    Augmented Dickey-Fuller Test on "{name}"', "\n   ", '-'*47)
    print(f' Null Hypothesis: Data has unit root. Non-Stationary.')
    print(f' Significance Level    = {signif}')
    print(f' Test Statistic        = {output["test_statistic"]}')
    print(f' No. Lags Chosen       = {output["n_lags"]}')

    for key,val in r[4].items():
        print(f' Critical value {adjust(key)} = {round(val, 3)}')

    if p_value <= signif:
        print(f" => P-Value = {p_value}. Rejecting Null Hypothesis.")
        print(f" => Series is Stationary.")
    else:
        print(f" => P-Value = {p_value}. Weak evidence to reject the Null Hypothesis.")
        print(f" => Series is Non-Stationary.")

# %%
# ADF Test on each column
for name, column in train.iteritems():
    adfuller_test(column, name=column.name)
    print('\n')
# Out:
#     Augmented Dickey-Fuller Test on "retail and recreation"
#     -----------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = -2.0113
#  No. Lags Chosen       = 13
#  Critical value 1%     = -3.475
#  Critical value 5%     = -2.881
#  Critical value 10%    = -2.577
#  => P-Value = 0.2816. Weak evidence to reject the Null Hypothesis.
#  => Series is Non-Stationary.
#
#
#     Augmented Dickey-Fuller Test on "parks"
#     -----------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = -8.7384
#  No. Lags Chosen       = 0
#  Critical value 1%     = -3.472
#  Critical value 5%     = -2.88
#  Critical value 10%    = -2.576
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#     Augmented Dickey-Fuller Test on "transit stations"
#     -----------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = -3.9448
#  No. Lags Chosen       = 9
#  Critical value 1%     = -3.474
#  Critical value 5%     = -2.881
#  Critical value 10%    = -2.577
#  => P-Value = 0.0017. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#     Augmented Dickey-Fuller Test on "workplaces"
#     -----------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = -4.1915
#  No. Lags Chosen       = 9
#  Critical value 1%     = -3.474
#  Critical value 5%     = -2.881
#  Critical value 10%    = -2.577
#  => P-Value = 0.0007. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#     Augmented Dickey-Fuller Test on "residential"
#     -----------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = -3.2492
#  No. Lags Chosen       = 10
#  Critical value 1%     = -3.474
#  Critical value 5%     = -2.881
#  Critical value 10%    = -2.577
#  => P-Value = 0.0173. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#     Augmented Dickey-Fuller Test on "driving"
#     -----------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = -1.2379
#  No. Lags Chosen       = 10
#  Critical value 1%     = -3.474
#  Critical value 5%     = -2.881
#  Critical value 10%    = -2.577
#  => P-Value = 0.6571. Weak evidence to reject the Null Hypothesis.
#  => Series is Non-Stationary.
#
#
#     Augmented Dickey-Fuller Test on "m50"
#     -----------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = -2.3326
#  No. Lags Chosen       = 7
#  Critical value 1%     = -3.474
#  Critical value 5%     = -2.88
#  Critical value 10%    = -2.577
#  => P-Value = 0.1617. Weak evidence to reject the Null Hypothesis.
#  => Series is Non-Stationary.
#
#
#     Augmented Dickey-Fuller Test on "m50_index"
#     -----------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = -2.3493
#  No. Lags Chosen       = 7
#  Critical value 1%     = -3.474
#  Critical value 5%     = -2.88
#  Critical value 10%    = -2.577
#  => P-Value = 0.1566. Weak evidence to reject the Null Hypothesis.
#  => Series is Non-Stationary.
#
#
#     Augmented Dickey-Fuller Test on "mask_rule_active"
#     -----------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = -1.6136
#  No. Lags Chosen       = 0
#  Critical value 1%     = -3.472
#  Critical value 5%     = -2.88
#  Critical value 10%    = -2.576
#  => P-Value = 0.4761. Weak evidence to reject the Null Hypothesis.
#  => Series is Non-Stationary.
#
#
#     Augmented Dickey-Fuller Test on "mask_wearing_percent"
#     -----------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = -1.6136
#  No. Lags Chosen       = 0
#  Critical value 1%     = -3.472
#  Critical value 5%     = -2.88
#  Critical value 10%    = -2.576
#  => P-Value = 0.4761. Weak evidence to reject the Null Hypothesis.
#  => Series is Non-Stationary.
#
#
#     Augmented Dickey-Fuller Test on "New Cases/1k population"
#     -----------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = -2.6107
#  No. Lags Chosen       = 4
#  Critical value 1%     = -3.473
#  Critical value 5%     = -2.88
#  Critical value 10%    = -2.577
#  => P-Value = 0.0908. Weak evidence to reject the Null Hypothesis.
#  => Series is Non-Stationary.

# %% [markdown]
# ## Make data stationery

# %% [markdown]
# ### 1st Differencing

# %%
# 1st difference
df_differenced = train.diff().dropna()

# %%
# ADF Test on each column of 1st Differences Dataframe
for name, column in df_differenced.iteritems():
    adfuller_test(column, name=column.name)
    print('\n')
# Out:
#     Augmented Dickey-Fuller Test on "retail and recreation"
#     -----------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = -3.8318
#  No. Lags Chosen       = 12
#  Critical value 1%     = -3.475
#  Critical value 5%     = -2.881
#  Critical value 10%    = -2.577
#  => P-Value = 0.0026. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#     Augmented Dickey-Fuller Test on "parks"
#     -----------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = -7.094
#  No. Lags Chosen       = 12
#  Critical value 1%     = -3.475
#  Critical value 5%     = -2.881
#  Critical value 10%    = -2.577
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#     Augmented Dickey-Fuller Test on "transit stations"
#     -----------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = -2.728
#  No. Lags Chosen       = 7
#  Critical value 1%     = -3.474
#  Critical value 5%     = -2.881
#  Critical value 10%    = -2.577
#  => P-Value = 0.0693. Weak evidence to reject the Null Hypothesis.
#  => Series is Non-Stationary.
#
#
#     Augmented Dickey-Fuller Test on "workplaces"
#     -----------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = -2.9075
#  No. Lags Chosen       = 8
#  Critical value 1%     = -3.474
#  Critical value 5%     = -2.881
#  Critical value 10%    = -2.577
#  => P-Value = 0.0445. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#     Augmented Dickey-Fuller Test on "residential"
#     -----------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = -2.6074
#  No. Lags Chosen       = 11
#  Critical value 1%     = -3.475
#  Critical value 5%     = -2.881
#  Critical value 10%    = -2.577
#  => P-Value = 0.0915. Weak evidence to reject the Null Hypothesis.
#  => Series is Non-Stationary.
#
#
#     Augmented Dickey-Fuller Test on "driving"
#     -----------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = -2.3596
#  No. Lags Chosen       = 9
#  Critical value 1%     = -3.474
#  Critical value 5%     = -2.881
#  Critical value 10%    = -2.577
#  => P-Value = 0.1535. Weak evidence to reject the Null Hypothesis.
#  => Series is Non-Stationary.
#
#
#     Augmented Dickey-Fuller Test on "m50"
#     -----------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = -3.9349
#  No. Lags Chosen       = 6
#  Critical value 1%     = -3.474
#  Critical value 5%     = -2.88
#  Critical value 10%    = -2.577
#  => P-Value = 0.0018. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#     Augmented Dickey-Fuller Test on "m50_index"
#     -----------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = -3.9167
#  No. Lags Chosen       = 6
#  Critical value 1%     = -3.474
#  Critical value 5%     = -2.88
#  Critical value 10%    = -2.577
#  => P-Value = 0.0019. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#     Augmented Dickey-Fuller Test on "mask_rule_active"
#     -----------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = -12.6491
#  No. Lags Chosen       = 0
#  Critical value 1%     = -3.472
#  Critical value 5%     = -2.88
#  Critical value 10%    = -2.576
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#     Augmented Dickey-Fuller Test on "mask_wearing_percent"
#     -----------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = -12.6491
#  No. Lags Chosen       = 0
#  Critical value 1%     = -3.472
#  Critical value 5%     = -2.88
#  Critical value 10%    = -2.576
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#     Augmented Dickey-Fuller Test on "New Cases/1k population"
#     -----------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = -8.8854
#  No. Lags Chosen       = 4
#  Critical value 1%     = -3.473
#  Critical value 5%     = -2.88
#  Critical value 10%    = -2.577
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.

# %% [markdown]
# ### 2nd Differencing

# %%
# Second Differencing
df_differenced = df_differenced.diff().dropna()

# %%
# ADF Test on each column of 2nd Differences Dataframe
for name, column in df_differenced.iteritems():
    adfuller_test(column, name=column.name)
    print('\n')
# Out:
#     Augmented Dickey-Fuller Test on "retail and recreation"
#     -----------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = -5.0527
#  No. Lags Chosen       = 13
#  Critical value 1%     = -3.476
#  Critical value 5%     = -2.882
#  Critical value 10%    = -2.577
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#     Augmented Dickey-Fuller Test on "parks"
#     -----------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = -7.641
#  No. Lags Chosen       = 14
#  Critical value 1%     = -3.476
#  Critical value 5%     = -2.882
#  Critical value 10%    = -2.578
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#     Augmented Dickey-Fuller Test on "transit stations"
#     -----------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = -8.4779
#  No. Lags Chosen       = 7
#  Critical value 1%     = -3.474
#  Critical value 5%     = -2.881
#  Critical value 10%    = -2.577
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#     Augmented Dickey-Fuller Test on "workplaces"
#     -----------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = -8.3471
#  No. Lags Chosen       = 9
#  Critical value 1%     = -3.475
#  Critical value 5%     = -2.881
#  Critical value 10%    = -2.577
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#     Augmented Dickey-Fuller Test on "residential"
#     -----------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = -9.0182
#  No. Lags Chosen       = 9
#  Critical value 1%     = -3.475
#  Critical value 5%     = -2.881
#  Critical value 10%    = -2.577
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#     Augmented Dickey-Fuller Test on "driving"
#     -----------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = -10.2904
#  No. Lags Chosen       = 8
#  Critical value 1%     = -3.474
#  Critical value 5%     = -2.881
#  Critical value 10%    = -2.577
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#     Augmented Dickey-Fuller Test on "m50"
#     -----------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = -8.2596
#  No. Lags Chosen       = 8
#  Critical value 1%     = -3.474
#  Critical value 5%     = -2.881
#  Critical value 10%    = -2.577
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#     Augmented Dickey-Fuller Test on "m50_index"
#     -----------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = -8.2665
#  No. Lags Chosen       = 8
#  Critical value 1%     = -3.474
#  Critical value 5%     = -2.881
#  Critical value 10%    = -2.577
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#     Augmented Dickey-Fuller Test on "mask_rule_active"
#     -----------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = -7.8831
#  No. Lags Chosen       = 6
#  Critical value 1%     = -3.474
#  Critical value 5%     = -2.881
#  Critical value 10%    = -2.577
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#     Augmented Dickey-Fuller Test on "mask_wearing_percent"
#     -----------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = -7.8831
#  No. Lags Chosen       = 6
#  Critical value 1%     = -3.474
#  Critical value 5%     = -2.881
#  Critical value 10%    = -2.577
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#     Augmented Dickey-Fuller Test on "New Cases/1k population"
#     -----------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = -7.0401
#  No. Lags Chosen       = 14
#  Critical value 1%     = -3.476
#  Critical value 5%     = -2.882
#  Critical value 10%    = -2.578
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.

# %% [markdown]
# ## Vector Autoregression (VAR) Model

# %%
#removing constant columns
train = train.loc[:, (train != train.iloc[0]).any()]


valid = valid.loc[:, (valid != valid.iloc[0]).any()]

# %%
df_differenced.columns
# Out:
# Index(['retail and recreation', 'parks', 'transit stations', 'workplaces',
#        'residential', 'driving', 'm50', 'm50_index', 'mask_rule_active',
#        'mask_wearing_percent', 'New Cases/1k population'],
#       dtype='object')

# %%
print(df_differenced.shape)

df_differenced_unique = df_differenced.drop_duplicates()
print(df_differenced_unique.shape)
# Out:
# (160, 11)
# (160, 11)

# %%
df_differenced_unique = df_differenced_unique.loc[:, (df_differenced_unique != df_differenced_unique.iloc[0]).any()]
print(df_differenced_unique.shape)
# Out:
# (160, 11)

# %%
df_differenced_unique.columns
# Out:
# Index(['retail and recreation', 'parks', 'transit stations', 'workplaces',
#        'residential', 'driving', 'm50', 'm50_index', 'mask_rule_active',
#        'mask_wearing_percent', 'New Cases/1k population'],
#       dtype='object')

# %%
model = VAR(df_differenced_unique)
for i in [4,5,6,7,8,9]:
    result = model.fit(i)
    print(result)
    print('Lag Order =', i)
    print('AIC : ', result.aic) ## take lag value where aic is low
    print('BIC : ', result.bic)
    print('FPE : ', result.fpe)
    print('HQIC: ', result.hqic, '\n')
# Out:
# <statsmodels.tsa.vector_ar.var_model.VARResultsWrapper object at 0x7f5229e61668>
# Lag Order = 4
# /usr/local/lib/python3.6/dist-packages/statsmodels/tsa/base/tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# <ipython-input-243-f70ff1d521b5> in <module>()
#       4     print(result)
#       5     print('Lag Order =', i)
# ----> 6     print('AIC : ', result.aic) ## take lag value where aic is low
#       7     print('BIC : ', result.bic)
#       8     print('FPE : ', result.fpe)
#
# /usr/local/lib/python3.6/dist-packages/statsmodels/base/wrapper.py in __getattribute__(self, attr)
#      33             pass
#      34
# ---> 35         obj = getattr(results, attr)
#      36         data = results.model.data
#      37         how = self._wrap_attrs.get(attr)
#
# /usr/local/lib/python3.6/dist-packages/statsmodels/tsa/vector_ar/var_model.py in aic(self)
#    2102     def aic(self):
#    2103         """Akaike information criterion"""
# -> 2104         return self.info_criteria['aic']
#    2105
#    2106     @property
#
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/decorators.py in __get__(self, obj, type)
#      91         _cachedval = _cache.get(name, None)
#      92         if _cachedval is None:
# ---> 93             _cachedval = self.fget(obj)
#      94             _cache[name] = _cachedval
#      95
#
# /usr/local/lib/python3.6/dist-packages/statsmodels/tsa/vector_ar/var_model.py in info_criteria(self)
#    2083         free_params = lag_order * neqs ** 2 + neqs * self.k_exog
#    2084
# -> 2085         ld = logdet_symm(self.sigma_u_mle)
#    2086
#    2087         # See Lütkepohl pp. 146-150
#
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/linalg.py in logdet_symm(m, check_symm)
#      26         if not np.all(m == m.T):  # would be nice to short-circuit check
#      27             raise ValueError("m is not symmetric.")
# ---> 28     c, _ = linalg.cho_factor(m, lower=True)
#      29     return 2*np.sum(np.log(c.diagonal()))
#      30
#
# /usr/local/lib/python3.6/dist-packages/scipy/linalg/decomp_cholesky.py in cho_factor(a, lower, overwrite_a, check_finite)
#     153     """
#     154     c, lower = _cholesky(a, lower=lower, overwrite_a=overwrite_a, clean=False,
# --> 155                          check_finite=check_finite)
#     156     return c, lower
#     157
#
# /usr/local/lib/python3.6/dist-packages/scipy/linalg/decomp_cholesky.py in _cholesky(a, lower, overwrite_a, clean, check_finite)
#      38     if info > 0:
#      39         raise LinAlgError("%d-th leading minor of the array is not positive "
# ---> 40                           "definite" % info)
#      41     if info < 0:
#      42         raise ValueError('LAPACK reported an illegal value in {}-th argument'
#
# LinAlgError: 10-th leading minor of the array is not positive definite

# %%
# Fit the model

model = VAR(endog=df_differenced_nonzero)
model_fit = model.fit()
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tsa/base/tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)

# %%
## need to check why summary is giving error

model_fit.summary()
# Out:
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# <ipython-input-99-12af76845b63> in <module>()
#       1 ## need to check why summary is giving error
#       2
# ----> 3 model_fit.summary()
#
# /usr/local/lib/python3.6/dist-packages/statsmodels/tsa/vector_ar/var_model.py in summary(self)
#    1687         summary : VARSummary
#    1688         """
# -> 1689         return VARSummary(self)
#    1690
#    1691     def irf(self, periods=10, var_decomp=None, var_order=None):
#
# /usr/local/lib/python3.6/dist-packages/statsmodels/tsa/vector_ar/output.py in __init__(self, estimator)
#      67     def __init__(self, estimator):
#      68         self.model = estimator
# ---> 69         self.summary = self.make()
#      70
#      71     def __repr__(self):
#
# /usr/local/lib/python3.6/dist-packages/statsmodels/tsa/vector_ar/output.py in make(self, endog_names, exog_names)
#      79
#      80         buf.write(self._header_table() + '\n')
# ---> 81         buf.write(self._stats_table() + '\n')
#      82         buf.write(self._coef_table() + '\n')
#      83         buf.write(self._resid_info() + '\n')
#
# /usr/local/lib/python3.6/dist-packages/statsmodels/tsa/vector_ar/output.py in _stats_table(self)
#     126                        'FPE:',
#     127                        'Det(Omega_mle):')
# --> 128         part2Ldata = [[model.neqs], [model.nobs], [model.llf], [model.aic]]
#     129         part2Rdata = [[model.bic], [model.hqic], [model.fpe], [model.detomega]]
#     130         part2Lheader = None
#
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/decorators.py in __get__(self, obj, type)
#      91         _cachedval = _cache.get(name, None)
#      92         if _cachedval is None:
# ---> 93             _cachedval = self.fget(obj)
#      94             _cache[name] = _cachedval
#      95
#
# /usr/local/lib/python3.6/dist-packages/statsmodels/tsa/vector_ar/var_model.py in llf(self)
#    1423     def llf(self):
#    1424         "Compute VAR(p) loglikelihood"
# -> 1425         return var_loglike(self.resid, self.sigma_u_mle, self.nobs)
#    1426
#    1427     @cache_readonly
#
# /usr/local/lib/python3.6/dist-packages/statsmodels/tsa/vector_ar/var_model.py in var_loglike(resid, omega, nobs)
#     325         \left(\ln\left|\Omega\right|-K\ln\left(2\pi\right)-K\right)
#     326     """
# --> 327     logdet = logdet_symm(np.asarray(omega))
#     328     neqs = len(omega)
#     329     part1 = - (nobs * neqs / 2) * np.log(2 * np.pi)
#
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/linalg.py in logdet_symm(m, check_symm)
#      26         if not np.all(m == m.T):  # would be nice to short-circuit check
#      27             raise ValueError("m is not symmetric.")
# ---> 28     c, _ = linalg.cho_factor(m, lower=True)
#      29     return 2*np.sum(np.log(c.diagonal()))
#      30
#
# /usr/local/lib/python3.6/dist-packages/scipy/linalg/decomp_cholesky.py in cho_factor(a, lower, overwrite_a, check_finite)
#     153     """
#     154     c, lower = _cholesky(a, lower=lower, overwrite_a=overwrite_a, clean=False,
# --> 155                          check_finite=check_finite)
#     156     return c, lower
#     157
#
# /usr/local/lib/python3.6/dist-packages/scipy/linalg/decomp_cholesky.py in _cholesky(a, lower, overwrite_a, clean, check_finite)
#      38     if info > 0:
#      39         raise LinAlgError("%d-th leading minor of the array is not positive "
# ---> 40                           "definite" % info)
#      41     if info < 0:
#      42         raise ValueError('LAPACK reported an illegal value in {}-th argument'
#
# LinAlgError: 11-th leading minor of the array is not positive definite

# %% [markdown]
# ## Forecasting

# %%
# Make prediction on validation
prediction = model_fit.forecast(model_fit.y, steps=len(valid))
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/base/wrapper.py:35: FutureWarning: y is a deprecated alias for endog, will be removed in version 0.11.0
#   obj = getattr(results, attr)

# %% [markdown]
# ## Accuracy

# %%
NY_labeled_data_filter.dtypes
# Out:
# retail and recreation      float64
# grocery and pharmacy       float64
# parks                      float64
# transit stations           float64
# workplaces                 float64
# residential                float64
# driving                    float64
# m50                        float64
# m50_index                    int64
# mask_rule_active             int64
# mask_wearing_percent       float64
# New Cases/1k population    float64
# dtype: object

# %%
train.dtypes
# Out:
# retail and recreation      float64
# grocery and pharmacy       float64
# parks                      float64
# transit stations           float64
# workplaces                 float64
# residential                float64
# driving                    float64
# m50                        float64
# m50_index                    int64
# mask_rule_active             int64
# mask_wearing_percent       float64
# New Cases/1k population    float64
# dtype: object

# %%
# Convert array to DataFrame
cols = valid.columns #NY_labeled_data_filter.columns
pred = pd.DataFrame(index=range(0, len(prediction)), columns=[cols])

for j in range(0, len(cols)):
    for i in range(0, len(prediction)):
        pred.iloc[i][j] = prediction[i][j]
print(cols)
# Out:
# Index(['retail and recreation', 'grocery and pharmacy', 'parks',
#        'transit stations', 'workplaces', 'residential', 'driving', 'm50',
#        'm50_index', 'New Cases/1k population'],
#       dtype='object')

# %% [markdown]
# ### RMSE

# %%
# RMSE
import math
for i in cols:
    print(i)
    print('RMSE value for', i, 'is:', math.sqrt(mean_squared_error(pred[[i]], valid[[i]])))
# Out:
# retail and recreation
# RMSE value for retail and recreation is: 20.821811628373105
# grocery and pharmacy
# RMSE value for grocery and pharmacy is: 5.402576273516499
# parks
# RMSE value for parks is: 49.56905508658742
# transit stations
# RMSE value for transit stations is: 23.76425704368648
# workplaces
# RMSE value for workplaces is: 38.983582949331996
# residential
# RMSE value for residential is: 10.648739608713774
# driving
# RMSE value for driving is: 48.97777723825501
# m50
# RMSE value for m50 is: 3.2206976826373723
# m50_index
# RMSE value for m50_index is: 66.97796235330786
# New Cases/1k population
# RMSE value for New Cases/1k population is: 0.02950470097790948

# %% [markdown]
# ## Final Prediction

# %%
# Make final predictions
model = VAR(endog=NY_labeled_data_filter)
model_fit = model.fit()
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tsa/base/tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)

# %%
#model_fit.summary()
# Out:
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# <ipython-input-92-3f355fc47e11> in <module>()
# ----> 1 model_fit.summary()
#
# /usr/local/lib/python3.6/dist-packages/statsmodels/tsa/vector_ar/var_model.py in summary(self)
#    1687         summary : VARSummary
#    1688         """
# -> 1689         return VARSummary(self)
#    1690
#    1691     def irf(self, periods=10, var_decomp=None, var_order=None):
#
# /usr/local/lib/python3.6/dist-packages/statsmodels/tsa/vector_ar/output.py in __init__(self, estimator)
#      67     def __init__(self, estimator):
#      68         self.model = estimator
# ---> 69         self.summary = self.make()
#      70
#      71     def __repr__(self):
#
# /usr/local/lib/python3.6/dist-packages/statsmodels/tsa/vector_ar/output.py in make(self, endog_names, exog_names)
#      79
#      80         buf.write(self._header_table() + '\n')
# ---> 81         buf.write(self._stats_table() + '\n')
#      82         buf.write(self._coef_table() + '\n')
#      83         buf.write(self._resid_info() + '\n')
#
# /usr/local/lib/python3.6/dist-packages/statsmodels/tsa/vector_ar/output.py in _stats_table(self)
#     126                        'FPE:',
#     127                        'Det(Omega_mle):')
# --> 128         part2Ldata = [[model.neqs], [model.nobs], [model.llf], [model.aic]]
#     129         part2Rdata = [[model.bic], [model.hqic], [model.fpe], [model.detomega]]
#     130         part2Lheader = None
#
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/decorators.py in __get__(self, obj, type)
#      91         _cachedval = _cache.get(name, None)
#      92         if _cachedval is None:
# ---> 93             _cachedval = self.fget(obj)
#      94             _cache[name] = _cachedval
#      95
#
# /usr/local/lib/python3.6/dist-packages/statsmodels/tsa/vector_ar/var_model.py in llf(self)
#    1423     def llf(self):
#    1424         "Compute VAR(p) loglikelihood"
# -> 1425         return var_loglike(self.resid, self.sigma_u_mle, self.nobs)
#    1426
#    1427     @cache_readonly
#
# /usr/local/lib/python3.6/dist-packages/statsmodels/tsa/vector_ar/var_model.py in var_loglike(resid, omega, nobs)
#     325         \left(\ln\left|\Omega\right|-K\ln\left(2\pi\right)-K\right)
#     326     """
# --> 327     logdet = logdet_symm(np.asarray(omega))
#     328     neqs = len(omega)
#     329     part1 = - (nobs * neqs / 2) * np.log(2 * np.pi)
#
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/linalg.py in logdet_symm(m, check_symm)
#      26         if not np.all(m == m.T):  # would be nice to short-circuit check
#      27             raise ValueError("m is not symmetric.")
# ---> 28     c, _ = linalg.cho_factor(m, lower=True)
#      29     return 2*np.sum(np.log(c.diagonal()))
#      30
#
# /usr/local/lib/python3.6/dist-packages/scipy/linalg/decomp_cholesky.py in cho_factor(a, lower, overwrite_a, check_finite)
#     153     """
#     154     c, lower = _cholesky(a, lower=lower, overwrite_a=overwrite_a, clean=False,
# --> 155                          check_finite=check_finite)
#     156     return c, lower
#     157
#
# /usr/local/lib/python3.6/dist-packages/scipy/linalg/decomp_cholesky.py in _cholesky(a, lower, overwrite_a, clean, check_finite)
#      38     if info > 0:
#      39         raise LinAlgError("%d-th leading minor of the array is not positive "
# ---> 40                           "definite" % info)
#      41     if info < 0:
#      42         raise ValueError('LAPACK reported an illegal value in {}-th argument'
#
# LinAlgError: 11-th leading minor of the array is not positive definite

# %%
yhat = model_fit.forecast(model_fit.y, steps=1)
print(yhat)
# Out:
# [[ 2.46652198e-01  4.14998645e+00  4.58777048e+01  1.74421267e+00
#   -2.82437209e+01  6.62940612e+00  7.20563802e+01  4.28478023e+00
#    8.92442242e+01  1.02614161e+00  8.08599589e-01  8.05367664e-03]]
# /usr/local/lib/python3.6/dist-packages/statsmodels/base/wrapper.py:35: FutureWarning: y is a deprecated alias for endog, will be removed in version 0.11.0
#   obj = getattr(results, attr)

# %%
model_fit.plot_forecast(1)
